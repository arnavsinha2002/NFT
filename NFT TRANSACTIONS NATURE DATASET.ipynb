# %%
# !pip install pandas
# !pip install requests
# !pip install datetime
# !pip install gql
# Out:
# ...
#   Created wheel for gql: filename=gql-3.0.0-py2.py3-none-any.whl size=62212 sha256=3ff22cdf15145a910174874f4460641eb92008ee5c0f1fb2bf6b0695eedf21db
#   Stored in directory: c:\users\12138\appdata\local\pip\cache\wheels\c3\8e\92\d5749a6f2919d2313d60922149651062626848252574f1f7e5
# Successfully built gql
# ...

# %%
import pandas as pd

data = pd.read_csv(r'C:\Users\12138\Desktop\NFT Data\Data_API.csv')

data_top= data.head()
data_top
# Out:
# C:\Users\12138\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,1,2,4,6,8,9,10,14,15,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Smart_contract    ID_token  \
# 0            NaN  87094722.0
# 1            NaN  73044643.0
# 2            NaN  17107482.0
# 3            NaN  82230857.0
# 4            NaN  40925443.0
#
#                                     Transaction_hash  \
# 0  0xed9ff1c311a611e5c457ce0a49bbbb7ed55efca98842...
# 1  0xbc8412594ffa7382e8306215ece5b4e041fc641b1813...
# 2  0x92672baf5e9e23de230dee8e57ddf443ab6d5a336341...
# 3  0x3d157249e3083622c2d756f07a05caa3a76687288b32...
# 4  0xa892b3569dc8e6b3c7db93aade62372637ebbc61fb63...
#
#                                Seller_address Seller_username  \
# 0  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 1  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# ...

# %%
data.head()
# Out:
#   Smart_contract    ID_token  \
# 0            NaN  87094722.0
# 1            NaN  73044643.0
# 2            NaN  17107482.0
# 3            NaN  82230857.0
# 4            NaN  40925443.0
#
#                                     Transaction_hash  \
# 0  0xed9ff1c311a611e5c457ce0a49bbbb7ed55efca98842...
# 1  0xbc8412594ffa7382e8306215ece5b4e041fc641b1813...
# 2  0x92672baf5e9e23de230dee8e57ddf443ab6d5a336341...
# 3  0x3d157249e3083622c2d756f07a05caa3a76687288b32...
# 4  0xa892b3569dc8e6b3c7db93aade62372637ebbc61fb63...
#
#                                Seller_address Seller_username  \
# 0  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 1  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 2  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 3  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 4  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
#
#                                 Buyer_address Buyer_username  \
# ...

# %%
data.tail()
# Out:
#                                      Smart_contract  \
# 6071022  0xb932a70a57673d89f4acffbe830e8ed7f75fb9e0
# 6071023  0x495f947276749ce646f68ac8c248420045cb7b5e
# 6071024  0x495f947276749ce646f68ac8c248420045cb7b5e
# 6071025  0x495f947276749ce646f68ac8c248420045cb7b5e
# 6071026  0x495f947276749ce646f68ac8c248420045cb7b5e
#
#                                                   ID_token  \
# 6071022                                              16412
# 6071023  1062274196422536302774639391540663457511117433...
# 6071024  4602588071276327231659212203812866312085457052...
# 6071025  8060875342503467325201444233539848397816312727...
# 6071026  8060875342503467325201444233539848397816312727...
#
#                                           Transaction_hash  \
# 6071022  0x346561b3f7a233c4245f91c68940b2d750df26ef1b04...
# 6071023  0xd507715bb835252a65d572037ac8eb36854b05ecc672...
# 6071024  0x4cb90a775619a9483c003050de47c403fae957e5352b...
# ...

# %%
import numpy as np
import seaborn as sns

# %%
data.shape
# Out:
# (6071027, 24)

# %%
data.describe()
# Out:
#        Price_Crypto     Price_USD
# count  6.071027e+06  6.062744e+06
# mean   6.574200e+02  1.463413e+02
# std    1.217706e+06  5.488389e+03
# min    0.000000e+00  1.514250e-16
# 25%    2.400000e-02  2.277600e-01
# 50%    4.100000e-01  1.426470e+00
# 75%    5.000000e+00  1.385100e+01
# max    3.000000e+09  7.501893e+06

# %%
data.columns
# Out:
# Index(['Smart_contract', 'ID_token', 'Transaction_hash', 'Seller_address',
#        'Seller_username', 'Buyer_address', 'Buyer_username', 'Image_url_1',
#        'Image_url_2', 'Image_url_3', 'Image_url_4', 'Price_Crypto', 'Crypto',
#        'Price_USD', 'Name', 'Description', 'Collection', 'Market',
#        'Datetime_updated', 'Datetime_updated_seconds', 'Permanent_link',
#        'Unique_id_collection', 'Collection_cleaned', 'Category'],
#       dtype='object')

# %%
data['Category'].unique()
# Out:
# array(['Games', 'Art', 'Other', 'Collectible', 'Metaverse', 'Utility'],
#       dtype=object)

# %%
data['Collection_cleaned'].unique()
# Out:
# array(['Godsunchained', 'Cryptokittie', 'Oghodlergang', ...,
#        'Cryptobullrun', 'Szabotage', 'Ataricapsulecollection'],
#       dtype=object)

# %%
data['Collection'].unique()
# Out:
# array(['Godsunchained', 'Cryptokitties', 'oghodlergang', ..., 'Szabotage',
#        'Atari-capsule-collection', 'Polymoji-buffet-food-drink'],
#       dtype=object)

# %%
pd.value_counts(data.Collection_cleaned)
# Out:
# Alien                     1290146
# Cryptokittie              1092177
# Godsunchained              622917
# Stf.capcom                 318737
# Kogsofficial               300854
#                            ...
# Skatecard                       1
# Pinupart                        1
# Doggeandmusk                    1
# Matchboxtwentyofficial          1
# Cthorcatclub                    1
# Name: Collection_cleaned, Length: 4624, dtype: int64

# %%
pd.value_counts(data.Collection)
# Out:
# alien.worlds            1288810
# Cryptokitties           1092177
# Gods-unchained           383965
# stf.capcom               318737
# kogsofficial             300854
#                          ...
# cryptmaniart                  1
# It-s-crazy-out-there          1
# katieartwork                  1
# 13richcrypto                  1
# Cryptodinosaurs               1
# Name: Collection, Length: 6283, dtype: int64

# %%
pd.value_counts(data.Category)
# Out:
# Games          2643014
# Collectible    1605657
# Art            1472515
# Other           272772
# Metaverse        68372
# Utility           8697
# Name: Category, dtype: int64

# %%
data.isnull().sum()
# Out:
# Smart_contract               961610
# ID_token                          0
# Transaction_hash            3185640
# Seller_address                    0
# Seller_username             4977773
# Buyer_address                     0
# Buyer_username              5178164
# Image_url_1                   54798
# Image_url_2                 1122022
# Image_url_3                 1032330
# Image_url_4                 1036942
# Price_Crypto                      0
# Crypto                            0
# Price_USD                      8283
# Name                        4219063
# Description                 4340298
# Collection                        0
# Market                            0
# Datetime_updated                  0
# Datetime_updated_seconds          0
# Permanent_link              4163765
# Unique_id_collection              0
# Collection_cleaned                0
# Category                          0
# dtype: int64

# %%
corelation= data.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns,
           annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.relplot(x='Price_Crypto', y='Price_USD',hue='Market',data=data)

# %%
games= data[data.Category.isin(['Games'])]
games.head()
# Out:
#   Smart_contract    ID_token  \
# 0            NaN  87094722.0
# 1            NaN  73044643.0
# 2            NaN  17107482.0
# 3            NaN  82230857.0
# 4            NaN  40925443.0
#
#                                     Transaction_hash  \
# 0  0xed9ff1c311a611e5c457ce0a49bbbb7ed55efca98842...
# 1  0xbc8412594ffa7382e8306215ece5b4e041fc641b1813...
# 2  0x92672baf5e9e23de230dee8e57ddf443ab6d5a336341...
# 3  0x3d157249e3083622c2d756f07a05caa3a76687288b32...
# 4  0xa892b3569dc8e6b3c7db93aade62372637ebbc61fb63...
#
#                                Seller_address Seller_username  \
# 0  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 1  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 2  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 3  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 4  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
#
#                                 Buyer_address Buyer_username  \
# ...

# %%
games.describe()
# Out:
#        Price_Crypto     Price_USD
# count  2.643014e+06  2.641093e+06
# mean   4.735259e+01  2.679706e+01
# std    2.598335e+03  8.427894e+02
# min    0.000000e+00  1.514250e-16
# 25%    4.200000e-02  8.772300e-02
# 50%    4.500000e-01  3.503700e-01
# 75%    2.400000e+00  3.702300e+00
# max    2.000000e+06  5.149742e+05

# %%
collectible= data[data.Category.isin(['Collectible'])]
collectible.describe()
# Out:
#        Price_Crypto     Price_USD
# count  1.605657e+06  1.604886e+06
# mean   1.896790e+02  6.843863e+01
# std    1.668442e+04  7.069136e+02
# min    4.000000e-18  9.558400e-16
# 25%    5.780000e-01  5.463000e-01
# 50%    4.500000e+00  2.090800e+00
# 75%    2.000000e+01  2.204983e+01
# max    9.000000e+06  4.291656e+05

# %%
art= data[data.Category.isin(['Art'])]
art.describe()
# Out:
#        Price_Crypto     Price_USD
# count  1.472515e+06  1.470669e+06
# mean   9.073167e+00  4.132374e+02
# std    4.943859e+02  1.058270e+04
# min    0.000000e+00  2.264600e-16
# 25%    5.000000e-03  1.090125e+00
# 50%    1.956634e-02  5.662232e+00
# 75%    1.288588e-01  3.441477e+01
# max    4.300000e+05  7.501893e+06

# %%
other= data[data.Category.isin(['Other'])]
other.describe()
# Out:
#        Price_Crypto     Price_USD
# count  2.727720e+05  2.692390e+05
# mean   1.155911e+04  8.155263e+01
# std    5.744339e+06  5.712562e+02
# min    2.000000e-16  3.831500e-10
# 25%    6.000000e-02  1.888000e-01
# 50%    8.900000e-01  1.914250e+00
# 75%    9.900000e+00  1.920932e+01
# max    3.000000e+09  9.984975e+04

# %%
metaverse= data[data.Category.isin(['Metaverse'])]
metaverse.describe()
# Out:
#        Price_Crypto     Price_USD
# count  6.837200e+04  6.816000e+04
# mean   5.776099e+03  1.000340e+03
# std    1.160912e+05  1.474081e+04
# min    3.960000e-07  1.619323e-04
# 25%    4.900000e-01  1.627800e+00
# 50%    4.000000e+00  5.429597e+01
# 75%    3.000000e+02  5.172901e+02
# max    2.894062e+07  2.684347e+06

# %%
print("Total Price in terms of Crypto for the category Games is:",games["Price_Crypto"].sum())
print("Total Price in terms of USD for the category Games is:",games["Price_USD"].sum())
# Out:
# Total Price in terms of Crypto for the category Games is: 125153551.5362975
# Total Price in terms of USD for the category Games is: 70773516.00417286

# %%
print("Total Price in terms of Crypto for the category Collectible is:",collectible["Price_Crypto"].sum())
print("Total Price in terms of USD for the category Collectible is:",collectible["Price_USD"].sum())
# Out:
# Total Price in terms of Crypto for the category Collectible is: 304559401.7296896
# Total Price in terms of USD for the category Collectible is: 109836195.67390439

# %%
print("Total Price in terms of Crypto for the category Art is:",art["Price_Crypto"].sum())
print("Total Price in terms of USD for the category Art is:",art["Price_USD"].sum())
# Out:
# Total Price in terms of Crypto for the category Art is: 13360373.80241907
# Total Price in terms of USD for the category Art is: 607735452.0443895

# %%
print("Total Price in terms of Crypto for the category Other is:",other["Price_Crypto"].sum())
print("Total Price in terms of USD for the category Other is:",other["Price_USD"].sum())
# Out:
# Total Price in terms of Crypto for the category Other is: 3153001668.513534
# Total Price in terms of USD for the category Other is: 21957147.645583097

# %%
print("Total Price in terms of Crypto for the category Metaverse is:", metaverse["Price_Crypto"].sum())
print("Total Price in terms of USD for the category Metaverse is:",metaverse["Price_USD"].sum())
# Out:
# Total Price in terms of Crypto for the category Metaverse is: 394923433.8470564
# Total Price in terms of USD for the category Metaverse is: 68183181.39469913

# %%
# MARKET ANALYSIS

# %%
data['Market'].unique()
# Out:
# array(['Godsunchained', 'Cryptokitties', 'Atomic', 'Decentraland',
#        'OpenSea'], dtype=object)

# %%
godsunchained= data[data.Market.isin(['Godsunchained'])]
godsunchained.describe()
# Out:
#        Price_Crypto     Price_USD
# count  2.362100e+05  2.362100e+05
# mean   3.900550e-02  8.947059e+00
# std    2.593025e-01  1.474722e+02
# min    1.000000e-18  1.514250e-16
# 25%    9.000000e-04  1.296090e-01
# 50%    2.500000e-03  3.855740e-01
# 75%    2.300000e-02  3.592800e+00
# max    2.700000e+01  2.250568e+04

# %%
cryptokitties= data[data.Market.isin(['Cryptokitties'])]
cryptokitties.describe()
# Out:
#        Price_Crypto     Price_USD
# count  7.254000e+05  7.250520e+05
# mean   8.788970e-02  4.336074e+01
# std    1.499275e+00  7.354932e+02
# min    1.000000e-18  8.477850e-16
# 25%    4.539769e-03  1.313813e+00
# 50%    1.000000e-02  5.508609e+00
# 75%    4.433620e-02  2.007602e+01
# max    6.000000e+02  1.735590e+05

# %%
atomic= data[data.Market.isin(['Atomic'])]
atomic.describe()
# Out:
#        Price_Crypto     Price_USD
# count  3.185292e+06  3.185292e+06
# mean   8.564872e+01  1.080231e+01
# std    1.784508e+03  1.729033e+02
# min    1.000000e-08  3.680000e-10
# 25%    6.000000e-01  1.057800e-01
# 50%    3.980000e+00  5.151500e-01
# 75%    2.000000e+01  2.381438e+00
# max    1.500000e+06  9.006872e+04

# %%
decentraland= data[data.Market.isin(['Decentraland'])]
decentraland.describe()
# Out:
#        Price_Crypto      Price_USD
# count  1.686300e+04   16863.000000
# mean   1.400394e+04    1393.293620
# std    5.060384e+04    6521.464164
# min    1.000000e+00       0.020425
# 25%    5.900000e+01       2.295100
# 50%    8.500000e+02      56.751500
# 75%    1.380000e+04     927.491250
# max    2.772000e+06  296355.000000

# %%
opensea= data[data.Market.isin(['OpenSea'])]
opensea.describe()
# Out:
#        Price_Crypto     Price_USD
# count  1.907262e+06  1.899327e+06
# mean   1.825746e+03  4.189769e+02
# std    2.172536e+06  9.766780e+03
# min    0.000000e+00  2.264600e-16
# 25%    5.000000e-03  1.146930e+00
# 50%    3.298903e-02  1.372035e+01
# 75%    1.250000e-01  8.522910e+01
# max    3.000000e+09  7.501893e+06

# %%
print("Total Price in terms of Crypto for the Market Godsunchained  is:", godsunchained["Price_Crypto"].sum())
print("Total Price in terms of USD for the Market Godsunchained is:",godsunchained["Price_USD"].sum())
# Out:
# Total Price in terms of Crypto for the Market Godsunchained  is: 9213.48920947116
# Total Price in terms of USD for the Market Godsunchained is: 2113384.760117187

# %%
print("Total Price in terms of Crypto for the Market Cryptokitties is:", cryptokitties["Price_Crypto"].sum())
print("Total Price in terms of USD for the Market Cryptokitties is:",cryptokitties["Price_USD"].sum())
# Out:
# Total Price in terms of Crypto for the Market Cryptokitties is: 63755.188679258106
# Total Price in terms of USD for the Market Cryptokitties is: 31438792.34633259

# %%
print("Total Price in terms of Crypto for the Market Atomic is:", atomic["Price_Crypto"].sum())
print("Total Price in terms of USD for the Market Atomic is:",atomic["Price_USD"].sum())
# Out:
# Total Price in terms of Crypto for the Market Atomic is: 272816192.69963765
# Total Price in terms of USD for the Market Atomic is: 34408508.002161406

# %%
print("Total Price in terms of Crypto for the Market Decentraland is:", decentraland["Price_Crypto"].sum())
print("Total Price in terms of USD for the Market Decentraland is:",decentraland["Price_USD"].sum())
# Out:
# Total Price in terms of Crypto for the Market Decentraland is: 236148381.0
# Total Price in terms of USD for the Market Decentraland is: 23495110.315095

# %%
print("Total Price in terms of Crypto for the Market OpenSea  is:", opensea["Price_Crypto"].sum())
print("Total Price in terms of USD for the Market OpenSea is:",opensea["Price_USD"].sum())
# Out:
# Total Price in terms of Crypto for the Market OpenSea  is: 3482176772.478944
# Total Price in terms of USD for the Market OpenSea is: 795774046.4194285

# %%
opensea.head()
# Out:
#                                      Smart_contract ID_token  \
# 4163765  0x06012c8cf97bead5deae237070f9587f8e7a266d   570964
# 4163766  0x06012c8cf97bead5deae237070f9587f8e7a266d   553057
# 4163767  0x06012c8cf97bead5deae237070f9587f8e7a266d   422030
# 4163768  0x06012c8cf97bead5deae237070f9587f8e7a266d   551265
# 4163769  0x06012c8cf97bead5deae237070f9587f8e7a266d   561824
#
#                                           Transaction_hash  \
# 4163765  0xb9fa19b74de10a091c53043aa9f9d84c3233366a0abf...
# 4163766  0x1e886781c29a6fa6cb02d5b5407a125194930b9cd20e...
# 4163767  0x7bb2f01c8d30383927ba677efb0ead9a3d796e8bdf24...
# 4163768  0x78dfb2e6f8fd82f811eddbbc495bf7e0206284c85244...
# 4163769  0xf465d5c0736e522b152c380331d45c0886d0e17eadb6...
#
#                                      Seller_address Seller_username  \
# 4163765  0xa21037849678af57f9865c6b9887f4e339f6377a             NaN
# 4163766  0x491677edd34020bf644fd63b5d65113fb3b74b10             NaN
# ...

# %%
opensea.count()
# Out:
# Smart_contract              1907262
# ID_token                    1907262
# Transaction_hash            1907262
# Seller_address              1907262
# Seller_username             1093254
# Buyer_address               1907262
# Buyer_username               892863
# Image_url_1                 1904345
# Image_url_2                 1814736
# Image_url_3                 1904428
# Image_url_4                 1899816
# Price_Crypto                1907262
# Crypto                      1907262
# Price_USD                   1899327
# Name                        1851964
# Description                 1730729
# Collection                  1907262
# Market                      1907262
# Datetime_updated            1907262
# Datetime_updated_seconds    1907262
# Permanent_link              1907262
# Unique_id_collection        1907262
# Collection_cleaned          1907262
# Category                    1907262
# dtype: int64

# %%
# !pip install pyxll
from pyxll import xl_func

# %%
if opensea["Seller_address"].any()==opensea["Buyer_address"].any():
    print("There is a match")
else: 
    print("no match")
# Out:
# no match

# %%
if opensea["Seller_username"].any()==opensea["Buyer_username"].any():
    print("There is a match")
else: 
    print("no match")
# Out:
# no match

# %%
if data["Seller_address"].any()==data["Buyer_address"].any():
    print("There is a match")
else: 
    print("no match")
# Out:
# no match

# %%
if data["Seller_username"].any()==data["Buyer_username"].any():
    print("There is a match")
else: 
    print("no match")
# Out:
# no match

# %%
opensea.shape
# Out:
# (1907262, 24)
